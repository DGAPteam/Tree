# %%
from Bio import Phylo
tree = Phylo.read("yeast_strains.newick", "newick")
Phylo.draw_ascii(tree)
# Out:
#   _ 15V-P4
#  |
#  |            ____ 74-D694
#  |           |
#  |           |   _____ EC9-8
#  |           |  |
#  |           |  |                  _____________________________ Y10
#  |           |  |            _____|
#  |           |  |           |     | YJM269
#  |           |  |          ,|
#  |           |  |          ||          ____ DBVPG6044
#  |           |  |          ||_________|
#  |           |  |        __|          |___ PW5
#  |           |  |       |  |
#  |           |  |       |  |          , YPS163
#  |       ____|  |       |  |    ______|
#  |      |    |  |    ___|  |___|      | YPS128
#  |      |    |  |   |   |      |
#  |      |    |  |   |   |      |_____ T7
#  |      |    |  |   |   |
#  |      |    |  |   |   |___________ UWOPS05-21
#  |      |    |  |   |
#  |      |    |  |   |           ____________ YJM339
#  |      |    |  |   |          |
#  |      |    |  |   |          |        ______ FostersO
#  |      |    |  |   |     _____|    ___|
# ...

# %%
from ete3 import Tree
t = Tree("yeast_strains.newick")
t.show()
